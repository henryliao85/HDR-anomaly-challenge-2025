# %%
import pandas as pd
import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# Original data

# %%
sns.histplot(pd.read_csv("/home/string-1/Documents/hdr_butterfly/HDR-anomaly-challenge-sample/notebook/sample_annotation.csv"), y = "classification", hue = "hybrid_stat")
# Out:
# <Axes: xlabel='Count', ylabel='classification'>

# %% [markdown]
# Augmented data used for training

# %%
sns.histplot(pd.read_csv("/home/string-1/Documents/hdr_butterfly/HDR-anomaly-challenge-sample/notebook/augmented_metadata.csv"), y = "classification", hue = "hybrid_stat")
# Out:
# <Axes: xlabel='Count', ylabel='classification'>
